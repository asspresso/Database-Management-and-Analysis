# %% [markdown]
# ## 1. import NYC_Accidents_2020.csv as a DataFrame

# %%
import pandas as pd

# %%
data = pd.read_csv("../data/raw/NYC_Accidents_2020.csv")
data = pd.read_csv("../data/raw/NYC_Accidents_2020.csv", header = 3)
data
# Out:
# C:\Users\Lucaw\AppData\Local\Temp\ipykernel_50292\2956452577.py:1: DtypeWarning: Columns (3,4,5,10,11,12,13,14,15,16,17,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("../data/raw/NYC_Accidents_2020.csv")
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0        8/29/20   15:40:00      BRONX   10466.0  40.892100 -73.833760
# 1        8/29/20   21:00:00   BROOKLYN   11221.0  40.690500 -73.919914
# 2        8/29/20   18:20:00        NaN       NaN  40.816500 -73.946556
# 3        8/29/20    0:00:00      BRONX   10459.0  40.824720 -73.892960
# 4        8/29/20   17:10:00   BROOKLYN   11203.0  40.649890 -73.933890
# ...          ...        ...        ...       ...        ...        ...
# 74876     1/1/20   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877     1/1/20    8:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878     1/1/20   11:36:00      BRONX   10461.0  40.848553 -73.830055
# ...

# %% [markdown]
# * We have to fix the issue by using the 'header' keyword argument, as the original data has the first three lines as notes.

# %% [markdown]
# ## 2. display columns and row samples

# %%
# show names of the columns
print(data.columns)
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
# show the first five rows
data.head(5)
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0    8/29/20   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1    8/29/20   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2    8/29/20   18:20:00       NaN       NaN  40.81650 -73.946556
# 3    8/29/20    0:00:00     BRONX   10459.0  40.82472 -73.892960
# 4    8/29/20   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# 1                  NaN  ...                    Unspecified
# ...

# %%
# show a random sampling of 5 rows
data.sample(5)
# Out:
#       CRASH DATE CRASH TIME   BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 73411     1/4/20   11:40:00       NaN       NaN        NaN        NaN
# 32680    4/24/20   12:41:00       NaN       NaN  40.751034  -73.89716
# 18067    6/30/20   21:00:00  BROOKLYN   11203.0  40.653780  -73.93108
# 61977    1/29/20   16:25:00     BRONX   10454.0  40.807190  -73.92431
# 64378    1/23/20   10:00:00       NaN       NaN  40.750885  -73.81942
#
#                           LOCATION                 ON STREET NAME  \
# 73411                          NaN  STATEN ISLAND EXPRESSWAY RAMP
# 32680  POINT (-73.89716 40.751034)     BROOKLYN QUEENS EXPRESSWAY
# 18067   POINT (-73.93108 40.65378)                            NaN
# 61977   POINT (-73.92431 40.80719)                EAST 135 STREET
# 64378  POINT (-73.81942 40.750885)              KISSENA BOULEVARD
#
#       CROSS STREET NAME       OFF STREET NAME  ...  \
# 73411               NaN                   NaN  ...
# ...

# %%
# show the last 5 rows
data.tail(5)
# Out:
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 74876     1/1/20   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877     1/1/20    8:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878     1/1/20   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879     1/1/20    1:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880     1/1/20   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION  ON STREET NAME CROSS STREET NAME  \
# 74876    POINT (-73.89651 40.82681)             NaN               NaN
# 74877   POINT (-73.95921 40.582935)             NaN               NaN
# 74878  POINT (-73.830055 40.848553)             NaN               NaN
# 74879   POINT (-73.96944 40.753624)  EAST 48 STREET          2 AVENUE
# 74880   POINT (-73.83096 40.726875)             NaN               NaN
#
#              OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# ...

# %% [markdown]
# ## 3. describe the rows and data types

# %%
# show the columns, types and non-missing values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74881 entries, 0 to 74880
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     74881 non-null  object
#  1   CRASH TIME                     74881 non-null  object
#  2   BOROUGH                        49140 non-null  object
#  3   ZIP CODE                       49134 non-null  float64
#  4   LATITUDE                       68935 non-null  float64
#  5   LONGITUDE                      68935 non-null  float64
#  6   LOCATION                       68935 non-null  object
#  7   ON STREET NAME                 55444 non-null  object
#  8   CROSS STREET NAME              35681 non-null  object
#  9   OFF STREET NAME                19437 non-null  object
#  10  NUMBER OF PERSONS INJURED      74881 non-null  int64
#  11  NUMBER OF PERSONS KILLED       74881 non-null  int64
# ...

# %% [markdown]
# ### Wrong or inappropriate types
# * Column 0 (CRASH DATE) should be datetime4 instead of object;
# * Column 3 (ZIP CODE) should be int64 instead of float64;
#
# ### Transformations and cleanings
# * We need to drop the 'ZIP CODE' and 'COLLISION_ID' column, because they are irrelevent to our investigation;
# * We need to drop the 'CONTRIBUTING FACTOR VEHICLE 5' and 'VEHICLE TYPE CODE 5' column, as they contain too many nulls;
# * We need to transform the 'CRASH DATE' column into datetime datatype
# * We need to transform NaN into 'OTHER' under the column of 'BOROUGH'

# %% [markdown]
# ## 4. initial column (or row) clean-up

# %%
# count the number of null in the two columns below
print(data['CONTRIBUTING FACTOR VEHICLE 5'].isna().sum())
print(data['VEHICLE TYPE CODE 5'].isna().sum())
# Out:
# 74358
# 74378

# %%
# remove the 3 columns below
data.drop("ZIP CODE", axis=1, inplace=True)
data.drop("COLLISION_ID", axis=1, inplace=True)
data.drop('CONTRIBUTING FACTOR VEHICLE 5', axis=1, inplace=True)
data.drop('VEHICLE TYPE CODE 5', axis=1, inplace=True)

# %% [markdown]
# * I removed 'ZIP CODE' column, 'COLLISION_ID' column, 'CONTRIBUTING FACTOR VEHICLE 5' column, and 'VEHICLE TYPE CODE 5' column.
# * 'ZIP CODE' and 'COLLISION_ID' column are removed because they are irrelevant to our investigation into the dataset;
# * 'CONTRIBUTING FACTOR VEHICLE 5' column and 'VEHICLE TYPE CODE 5' column are removed because they contain too many nulls, as shown above.

# %%
# transform the 'CRASH DATE' column
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# %% [markdown]
# * This column should be transformed because later on we will find the month with most accident occurance.

# %% [markdown]
# ## 5. determine the top three streets(Use the ON STREET NAME column) that had the most accidents

# %%
# count values of the 'ON STREET NAME' column
data['ON STREET NAME'].value_counts()
# Out:
# BELT PARKWAY                  1241
# LONG ISLAND EXPRESSWAY         745
# BROOKLYN QUEENS EXPRESSWAY     738
# FDR DRIVE                      728
# MAJOR DEEGAN EXPRESSWAY        591
#                               ...
# GULF AVENUE                      1
# E 170 St                         1
# BAYSIDE LANE                     1
# ES KOCH BRIDGE                   1
# CRESSKILL PLACE                  1
# Name: ON STREET NAME, Length: 4009, dtype: int64

# %% [markdown]
# ### From the chart above, we may notice the top 3 streets with the most accidents;
# * 1st place: BELT PARKWAY, 1241 accidents
# * 2nd place: LONG ISLAND EXPRESSWAY, 745 accidents
# * 3rd place: BROOKLYN QUEENS EXPRESSWAY, 738 accidents

# %% [markdown]
# ## 6. shows the number of accidents that occurred at each borough

# %%
# transform the 'BOROUGH' column by defining a function
# any other values than 'BROOKLYN', 'QUEENS', 'BRONX', 'MANHATTAN' and 'STATEN ISLAND' will be transformed to 'OTHER'
def convert_borough(borough):
    default = ['BROOKLYN', 'QUEENS', 'BRONX', 'MANHATTAN', 'STATEN ISLAND']
    if borough not in default:
        return 'OTHER'
    return borough
data['BOROUGH'] = data['BOROUGH'].map(lambda x: convert_borough(x))

# count values of the transformed 'BOROUGH' column
data['BOROUGH'].value_counts()
# Out:
# OTHER            25741
# BROOKLYN         16907
# QUEENS           14017
# BRONX             9417
# MANHATTAN         7353
# STATEN ISLAND     1446
# Name: BOROUGH, dtype: int64

# %%
# visualization to allow comparison between different boroughs
data['BOROUGH'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 7. calculate summary statistics for the number of persons injured in all NYC and for a couple of selected boroughs (you can choose the two boroughs)

# %%
# All NYC injuries statistics
data['NUMBER OF PERSONS INJURED'].describe()
# Out:
# count    74881.000000
# mean         0.366555
# std          0.726178
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         15.000000
# Name: NUMBER OF PERSONS INJURED, dtype: float64

# %%
# MANHATTAN injuries statistics
# establish a new dataframe to filter data for Manhattan only
manhattan_data = data[data['BOROUGH']=='MANHATTAN']
manhattan_data['NUMBER OF PERSONS INJURED'].describe()
# Out:
# count    7353.000000
# mean        0.292534
# std         0.584037
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         5.000000
# Name: NUMBER OF PERSONS INJURED, dtype: float64

# %%
# BROOKLYN injuries statistics
# establish a new dataframe to filter data for Brooklyn only
brooklyn_data = data[data['BOROUGH']=='BROOKLYN']
brooklyn_data['NUMBER OF PERSONS INJURED'].describe()
# Out:
# count    16907.000000
# mean         0.356302
# std          0.708303
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max         15.000000
# Name: NUMBER OF PERSONS INJURED, dtype: float64

# %% [markdown]
# ### From the results above, we notice that:
# * Mean: Manhattan has lower injuries mean than Brooklyn. Both Manhattan and Brooklyn have lower injuries mean than NYC as a whole.
# * Median (50 percentile): the medianis always 0.0, regardless of the borough.
# * 25 and 75 percentile: the 25 percentile is always 0; the 75 percentile is 1.0 for both Brooklyn and NYC as a whole, but 0.0 for Manhattan.
# * Max: Manhattan has a lower max injuries than Brooklyn (5 vs 15); Brooklyn has the same max injuries as NYC as a whole;
# * Min: the min injuries is always 0

# %% [markdown]
# ## 8. what are the distributions of accidents based on the geo location (latitude & longitude)?

# %%
import matplotlib.pyplot as plt

# establish a new dataframe with no (0, 0) data for location
b_data = data[(data['LATITUDE']!=0) & (data['LATITUDE']!=0)]

# establish new dataframes to filter data for various boroughs
manhattan_data = b_data[b_data['BOROUGH']=='MANHATTAN']
brooklyn_data = b_data[b_data['BOROUGH']=='BROOKLYN']
queens_data = b_data[b_data['BOROUGH']=='QUEENS']
bronx_data = b_data[b_data['BOROUGH']=='BRONX']
staten_data = b_data[b_data['BOROUGH']=='STATEN ISLAND']
other_data = b_data[b_data['BOROUGH']=='OTHER']

# plot the data in different colors
man = plt.scatter(manhattan_data['LONGITUDE'], manhattan_data['LATITUDE'], color='red', s=3)
que = plt.scatter(queens_data['LONGITUDE'], queens_data['LATITUDE'], color='green', s=3)
brk = plt.scatter(brooklyn_data['LONGITUDE'], brooklyn_data['LATITUDE'], color='orange', s=3)
bro = plt.scatter(bronx_data['LONGITUDE'], bronx_data['LATITUDE'], color='purple', s=3)
sta = plt.scatter(staten_data['LONGITUDE'], staten_data['LATITUDE'], color='blue', s=3)
oth = plt.scatter(other_data['LONGITUDE'], other_data['LATITUDE'], color='pink', alpha=0.05, s=3)
plt.legend((man, que, brk, bro, sta, oth), 
          ('Manhattan', 'Queen', 'Brooklyn', 'Bronx', 'Staten Island', 'Other'),
           scatterpoints=1,
           loc='upper left',
           ncol=2,
           fontsize=8)
plt.show()

# %% [markdown]
# ## 9. shows the covariance between each pair of the columns

# %% [markdown]
# * only numeric columns are selected
# * zipcode and collision_id are ruled out, as they are categorical data (the two columns have been dropped off in previous steps)
# * latitide and longitude are ruled out as well, because all accidents happened in NYC and the locations are relatively close to each other

# %%
# select necessary columns and show their covariance
cov_subset = data[['NUMBER OF PERSONS INJURED','NUMBER OF PERSONS KILLED', 
                  'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 
                  'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED', 
                  'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED']]
cov_subset.cov()
# Out:
#                                NUMBER OF PERSONS INJURED  \
# NUMBER OF PERSONS INJURED                       0.527334
# NUMBER OF PERSONS KILLED                        0.000617
# NUMBER OF PEDESTRIANS INJURED                   0.042047
# NUMBER OF PEDESTRIANS KILLED                   -0.000047
# NUMBER OF CYCLIST INJURED                       0.030986
# NUMBER OF CYCLIST KILLED                       -0.000044
# NUMBER OF MOTORIST INJURED                      0.454301
# NUMBER OF MOTORIST KILLED                       0.000708
#
#                                NUMBER OF PERSONS KILLED  \
# NUMBER OF PERSONS INJURED                      0.000617
# NUMBER OF PERSONS KILLED                       0.002267
# NUMBER OF PEDESTRIANS INJURED                 -0.000052
# NUMBER OF PEDESTRIANS KILLED                   0.000760
# NUMBER OF CYCLIST INJURED                     -0.000071
# NUMBER OF CYCLIST KILLED                       0.000120
# ...

# %% [markdown]
# ## 10. which month did the most number of accidents occur?

# %%
# create a new column called 'MONTH' to record exact month of the accidents
data['MONTH'] = data['CRASH DATE'].dt.month

# count values on the column 'MONTH'
month_freq = data['MONTH'].value_counts()
month_freq
# Out:
# 1    14287
# 2    13684
# 3    11057
# 7     9225
# 8     8747
# 6     7616
# 5     6149
# 4     4116
# Name: MONTH, dtype: int64

# %%
# create a new Series with month abbreviations instead of numbers
import calendar
monthabbr_freq = pd.Series(data = month_freq.values, index = month_freq.index.map(lambda x: calendar.month_abbr[x]))

# draw a bar plot to represent the frequency in terns of months
monthabbr_freq.plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# * According to the numbers and plot above, accidents are likely to reach a lull in April and May
# * However, the data only includes accidents happening during Jan and Aug
# * So we need more data (from Sep to Dec) to make further conclusions
